# %% [markdown]
# # Colab for roop-un4.4.1 - Gradio version
# https://github.com/C0untFloyd
# <br>
# New
# <br>
# https://codeberg.org/Cognibuild/ROOP-FLOYD
# <br>
# New
# <br>
# https://github.com/ravindergandhi/Roop-Un4.4.1

# %% [markdown]
# Step 1. Connect Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Step 2. Install CUDA 12.6 & CUDNN on Google Cloud Compute

# %%
# !apt-get -y update
# !apt-get -y install cuda-toolkit-12-6
# !apt-get -y install cudnn9-cuda-12

import os
os.environ["LD_LIBRARY_PATH"] += ":" + "/usr/local/cuda-12/lib64"
os.environ["LD_LIBRARY_PATH"] += ":" + "/usr/local/cuda-12.6/lib64"

# !nvcc --version

# %% [markdown]
# Step 3. Installing & preparing requirements

# %%
# !git clone https://github.com/ravindergandhi/Roop-Un4.4.1
# %cd Roop-Un4.4.1
# !mv config_colab.yaml config.yaml
# !pip install -r requirements.txt

# %% [markdown]
# Step 4. Running roop-unleashed with default config

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA device is available: {torch.cuda.is_available()}")

# !python run.py

# %% [markdown]
# <br><br>
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# <br><br>
# (Optional) Upgrade First<br><br>
# https://pypi.org/project/gradio/
# <br><br>
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
#!pip install gradio==5.34.0 --upgrade
# !pip install gradio==5.13.0 --upgrade
# !pip install --upgrade fastapi
# !pip install --force-reinstall pydantic==2.10.6
# !pip install "numpy<2.0"
#!pip install numpy<3.0.0,>=2.0.0
#!pip install torchaudio 2.6.0+cu124

# %% [markdown]
# ### Download generated images folder
# (only needed if you want to zip the generated output)

# %%
import shutil
import os
from google.colab import files

def zip_directory(directory_path, zip_path):
    shutil.make_archive(zip_path, 'zip', directory_path)

# Set the directory path you want to download
directory_path = '/content/Roop-Un4.4.1/output'

# Set the zip file name
zip_filename = 'fake_output.zip'

# Zip the directory
zip_directory(directory_path, zip_filename)

# Download the zip file
files.download(zip_filename+'.zip')
